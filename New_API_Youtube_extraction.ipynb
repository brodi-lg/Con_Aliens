# %% [markdown]
# {
#   "kind": "youtube#channel",
#   "etag": etag,
#   "id": string,
#   "snippet": {
#     "title": string,
#     "description": string,
#     "customUrl": string,
#     "publishedAt": datetime,
#     "thumbnails": {
#       (key): {
#         "url": string,
#         "width": unsigned integer,
#         "height": unsigned integer
#       }
#     },
#     "defaultLanguage": string,
#     "localized": {
#       "title": string,
#       "description": string
#     },
#     "country": string
#   },
#   "contentDetails": {
#     "relatedPlaylists": {
#       "likes": string,
#       "favorites": string,
#       "uploads": string
#     }
#   },
#   "statistics": {
#     "viewCount": unsigned long,
#     "subscriberCount": unsigned long,  // this value is rounded to three significant figures
#     "hiddenSubscriberCount": boolean,
#     "videoCount": unsigned long
#   },
#   "topicDetails": {
#     "topicIds": [
#       string
#     ],
#     "topicCategories": [
#       string
#     ]
#   },
#   "status": {
#     "privacyStatus": string,
#     "isLinked": boolean,
#     "longUploadsStatus": string,
#     "madeForKids": boolean,
#     "selfDeclaredMadeForKids": boolean
#   },
#   "brandingSettings": {
#     "channel": {
#       "title": string,
#       "description": string,
#       "keywords": string,
#       "trackingAnalyticsAccountId": string,
#       "unsubscribedTrailer": string,
#       "defaultLanguage": string,
#       "country": string
#     },
#     "watch": {
#       "textColor": string,
#       "backgroundColor": string,
#       "featuredPlaylistId": string
#     }
#   },
#   "auditDetails": {
#     "overallGoodStanding": boolean,
#     "communityGuidelinesGoodStanding": boolean,
#     "copyrightStrikesGoodStanding": boolean,
#     "contentIdClaimsGoodStanding": boolean
#   },
#   "contentOwnerDetails": {
#     "contentOwner": string,
#     "timeLinked": datetime
#   },
#   "localizations": {
#     (key): {
#       "title": string,
#       "description": string
#     }
#   }
# }

# %%
pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in /opt/anaconda3/lib/python3.12/site-packages (0.21.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv

# %%
import os

# %%
import requests

# %%
pip install google-api-python-client
# Out:
# Requirement already satisfied: google-api-python-client in /opt/anaconda3/lib/python3.12/site-packages (2.149.0)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in /opt/anaconda3/lib/python3.12/site-packages (from google-api-python-client) (0.22.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0 in /opt/anaconda3/lib/python3.12/site-packages (from google-api-python-client) (2.35.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from google-api-python-client) (0.2.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in /opt/anaconda3/lib/python3.12/site-packages (from google-api-python-client) (2.21.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /opt/anaconda3/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.65.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.19.5 in /opt/anaconda3/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.20.3)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /opt/anaconda3/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.24.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /opt/anaconda3/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.32.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/anaconda3/lib/python3.12/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/anaconda3/lib/python3.12/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (4.9)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /opt/anaconda3/lib/python3.12/site-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client) (3.0.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/anaconda3/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (0.4.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2024.7.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
from googleapiclient.discovery import build

# %%
load_dotenv()
# Out:
# True

# %%
my_key=os.getenv("API_KEY")

# %%
channel_id = 'UCIFk2uvCNcEmZ77g0ESKLcQ'

# %%
youtube = build('youtube', 'v3', developerKey=my_key)

# %%
import pandas as pd

# %%
import requests

# YouTube API URL to get channel details including topic details
url = f"https://www.googleapis.com/youtube/v3/channels?part=snippet,contentDetails,statistics,topicDetails&id={channel_id}&key={my_key}"

# Make the request and get the response
response = requests.get(url)
channel_data = response.json()

# Extract relevant information
if 'items' in channel_data and len(channel_data['items']) > 0:
    channel_info = channel_data['items'][0]
    
    # Get general channel information
    title = channel_info['snippet']['title']
    description = channel_info['snippet']['description']
    subscriber_count = channel_info['statistics'].get('subscriberCount', 'N/A')
    total_views = channel_info['statistics'].get('viewCount', 'N/A')
    video_count = channel_info['statistics'].get('videoCount', 'N/A')
    
    # Get topic details
    topic_ids = channel_info.get('topicDetails', {}).get('topicIds', [])
    topic_categories = channel_info.get('topicDetails', {}).get('topicCategories', [])
    
    # Display the information
    print(f"Channel Title: {title}")
    print(f"Description: {description}")
    print(f"Subscriber Count: {subscriber_count}")
    print(f"Total Views: {total_views}")
    print(f"Total Videos: {video_count}")
    
    # Display topic details
    print("\nTopic IDs:")
    if topic_ids:
        print(", ".join(topic_ids))
    else:
        print("No topic IDs found.")

    print("\nTopic Categories:")
    if topic_categories:
        print(", ".join(topic_categories))
    else:
        print("No topic categories found.")

else:
    print("No channel data found.")
# Out:
# Channel Title: The Why Files
# Description: The Why Files is a channel for people who are fascinated (obsessed) with mysteries, myths, legends and conspiracies. We tell stories, seek the truth, and have a few laughs along the way.
#
# 📬 Mailbox:
# Question Six or The Why Files
# 7582 Las Vegas Blvd
# #244
# Las Vegas, NV 89123
#
# 👓 Support TWF by purchasing from TWF store:
# https://shop.thewhyfiles.com
# ----
# 🙏 Support TWF and join our community:
# https://www.patreon.com/thewhyfiles
# ----
# 🔥 Have a tip, suggestions or want to say hi?
# https://thewhyfiles.com/tips OR discord https://thewhyfiles.com/discord
#
# ----
# OTHER CHANNELS
# https://www.youtube.com/c/TheWhyFilesBackstage
# https://www.youtube.com/c/HecklefishMoriarty
#
# #science #mysteries #urbanlegends
#
# 👇 The business email for PROFESSIONAL INQUIRIES ONLY, please! (personal email to AJ @ TWF)
#
# Subscriber Count: 4170000
# Total Views: 698360472
# Total Videos: 273
#
# Topic IDs:
# /m/01k8wb, /m/098wr
#
# Topic Categories:
# https://en.wikipedia.org/wiki/Knowledge, https://en.wikipedia.org/wiki/Society

# %%
# Function to get all videos from a channel
def get_all_channel_videos(channel_id):
    
    request = youtube.channels().list(part='contentDetails',id=channel_id)
    response = request.execute()
    
    # Check if the response contains items
    if 'items' not in response or len(response['items']) == 0:
        print("No videos found for this channel.")
        return []

    upload_playlist_id = response['items'][0]['contentDetails']['relatedPlaylists']['uploads']

    # Initialize an empty list to store videos
    all_videos = []

    # Paginate through all videos in the upload playlist
    next_page_token = None
    while True:
        request = youtube.playlistItems().list(
            part='snippet',
            playlistId=upload_playlist_id,
            maxResults=50,  # Maximum allowed by API
            pageToken=next_page_token
        )
        response = request.execute()
        all_videos.extend(response['items'])

        # Check if there's another page of results
        next_page_token = response.get('nextPageToken')
        if not next_page_token:
            break

    return all_videos

def get_video_details(video_id):
    request = youtube.videos().list(
        part='snippet',
        id=video_id
    )
    response = request.execute()

    # Ensure that there are items in the response and access the snippet
    if 'items' in response and len(response['items']) > 0:
        snippet = response['items'][0]['snippet']
        # Check if the 'statistics' field exists in the response
        statistics = response['items'][0].get('statistics', {})

        # Get relevant statistics
        view_count = statistics.get('viewCount', '0')  # Views
        like_count = statistics.get('likeCount', '0')  # Likes
        tags = snippet.get('tags', [])  # Tags might not be available for every video
       
        return view_count, like_count,tags
    return '0', '0', []


# Function to extract video details and convert to a DataFrame
def videos_to_dataframe(videos):
    # Create a list of dictionaries to store video details
    video_data = []

    for video in videos:
        # Ensure 'snippet' and 'resourceId' exist
        snippet = video.get('snippet', {})
        resource_id = snippet.get('resourceId', {})

        # Get the video ID and title
        video_id = resource_id.get('videoId')
        if not video_id:
            continue  # Skip if video ID is missing

        # Get video details
        view_count, like_count, tags = get_video_details(video_id)


        video_info = {
            'Title': snippet.get('title', 'No Title'),
            'Video ID': video_id,
            'Published At': snippet.get('publishedAt', 'Unknown Date'),
            'View Count': view_count,
            'Like Count': like_count,
            'Tags': ', '.join(tags) if tags else 'No Tags'
        }
        video_data.append(video_info)

    df = pd.DataFrame(video_data)
    return df

# Replace with the actual channel ID you want to investigate
channel_id = 'UCIFk2uvCNcEmZ77g0ESKLcQ' # Example channel ID

# Get all videos from the channel
all_videos = get_all_channel_videos(channel_id)

# Convert to a DataFrame including tags
if all_videos:
    df_videos = videos_to_dataframe(all_videos)
    # Display the DataFrame
    print(df_videos)
else:
    print("No videos retrieved from the channel.")
# Out:
#                                                  Title     Video ID  \
# 0    Project Blue Beam: Staging a Fake Alien Attack...  kaS8fP12CGM
# 1     COMPILATION: The Stories That Made Me a Believer  cHR-S4Ni7PE
# 2    Alien Implants Vol. 1: Devil’s Den UFO Encount...  SJek6PsN2xg
# 3    Operation Sunray | Hunting the Entity in the T...  t1eGM-dTZu0
# 4    Accidental Time Travelers | The Mystery and Sc...  vLfV9PowEbw
# ..                                                 ...          ...
# 268  Raining spiders, frogs, fish and ... meat. Yes...  16xhpv13DsM
# 269  ASMR: What it is, what it stands for and how i...  Hmy867m2QlQ
# 270  Top 10 Scariest Places You Can Actually Visit ...  HZpUbBDWLK0
# 271      Top 10 Terrifying Animals That Actually Exist  FNiXDiNsM9Q
# 272       15 Mind Blowing Math Facts | Insane but True  BR_8AxIwKV8
#
#              Published At View Count Like Count  \
# 0    2024-10-08T20:21:31Z          0          0
# 1    2024-09-20T01:10:29Z          0          0
# 2    2024-09-16T10:47:59Z          0          0
# 3    2024-09-01T05:00:08Z          0          0
# 4    2024-08-24T01:00:07Z          0          0
# ..                    ...        ...        ...
# 268  2020-11-06T02:29:34Z          0          0
# 269  2020-10-28T01:10:26Z          0          0
# 270  2020-10-23T05:01:58Z          0          0
# 271  2020-10-13T07:36:04Z          0          0
# 272  2020-10-05T07:29:26Z          0          0
#
#                                                   Tags
# 0                                              No Tags
# 1                                              No Tags
# 2                                              No Tags
# 3                                              No Tags
# 4                                              No Tags
# ..                                                 ...
# 268  animal rain, raining worms, raining spiders, r...
# 269  science, top 5, asmr tingles, personal attenti...
# 270  scary, scariest, creepy, haunted, ghosts, para...
# 271  weird animals, terrifying animals, scary anima...
# 272  amazing math facts, 15 amazing math facts, mat...
#
# [273 rows x 6 columns]

# %%
pip install isodate
# Out:
# Requirement already satisfied: isodate in /opt/anaconda3/lib/python3.12/site-packages (0.7.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
df_videos.to_csv('channel_videos.csv', index=False)

# %%
df_videos.to_excel('channel_videos.xlsx', index=False)

# %%
#video id 

def get_upload_playlist_id(channel_id):
    request = youtube.channels().list(
        part='contentDetails',
        id=channel_id
    )
    response = request.execute()
    
    if 'items' not in response or len(response['items']) == 0:
        print("Channel not found or has no videos.")
        return None

    # Get the upload playlist ID
    upload_playlist_id = response['items'][0]['contentDetails']['relatedPlaylists']['uploads']
    return upload_playlist_id

# Function to get all video IDs from a playlist
def get_video_ids_from_playlist(playlist_id):
    video_ids = []
    next_page_token = None

    while True:
        request = youtube.playlistItems().list(
            part='snippet',
            playlistId=playlist_id,
            maxResults=50,  # The maximum number of results per page (50)
            pageToken=next_page_token
        )
        response = request.execute()
        
        for item in response['items']:
            video_id = item['snippet']['resourceId']['videoId']
            video_ids.append(video_id)
        
        # Check if there is another page of results
        next_page_token = response.get('nextPageToken')
        if not next_page_token:
            break

    return video_ids

# Replace with the actual channel ID you want to investigate
channel_id = 'UCIFk2uvCNcEmZ77g0ESKLcQ'  # Example channel ID

# Get the upload playlist ID for the channel
upload_playlist_id = get_upload_playlist_id(channel_id)

# If the upload playlist ID is found, get the video IDs
if upload_playlist_id:
    video_ids = get_video_ids_from_playlist(upload_playlist_id)
    print(f"Video IDs retrieved: {video_ids}")

    # Optional: Convert the video IDs to a DataFrame for easier viewing or exporting
    df_video_ids = pd.DataFrame(video_ids, columns=['Video ID'])
    print(df_video_ids)
else:
    print("Failed to retrieve video IDs.")
# Out:
# Video IDs retrieved: ['kaS8fP12CGM', 'cHR-S4Ni7PE', 'SJek6PsN2xg', 't1eGM-dTZu0', 'vLfV9PowEbw', 'HCRZ1STWsCE', 'reXi0C1JoHo', 'IAEsS4IOrBk', 'OAzikSDmslU', 'BzRR4Yg6B3w', '2k7YTFrmt84', 'Nr5yk9mxzSI', 'zo68B3UG9VU', '7e4Csdyx_J0', 'WqHimq-PT_s', '2SpXMu-B5mU', 'Rg-Ocr5hNLI', 'mtfJFUeFofA', '-l_GdVh1LYE', 'VVMpple3CJc', 'OvcCK-F6aKY', 'xK0WZo04Cxo', 'purPO8UE-9g', 'EieUJvKrjo4', '-ZRwlYtAMps', 'DJuxIDyHZCw', 'vZBRMcUkqNA', 'Ymynk91cMas', 'Op_LNbZYQOQ', '4XP_m5-ULnA', 'UjCiFCKE4mY', 'rofTPRVwcas', '-1p0mvfzPS8', 'IQz7innxnms', 'GLP5UupAvSY', 'z_YeaMO2X0s', 'rRA5kyXgmrM', 'xxZLBncNRXs', '9Rs_e21MJvA', 'juyvnVL6V7g', 'D5DVy-ZCieA', 'tgqAt6YN1jE', 'XWqh9F4pjHg', 'UhXsyhXAe_M', 'GDL70lKAz0A', 'IlAS26MrbIk', 'pohEbP5IquU', '9PZeEvLwoYs', 'n84o7Ggw2Fw', 'SOr7vqmIwto', 'N0rAnnCoPCI', '4yEkCSyTTxg', 'CjA6oGWaP2k', '_nGePkIW3Ac', 'KhnrDrQNkyc', '8L6M2mRcux4', 'AazxDk1ODVo', 'j-tGHCHVM_o', 'SWa9BcDLf_Y', 'r4xzFWW-FAA', 'XLhMi6YEhsQ', 'eIgbsZ05O2A', 'uoi2dwH-1go', 'X2NgC5oisCo', 'M0DjcbGwoyQ', 'j_TTKx9ILi8', '24HeQwh60jY', 'TunNIAGN8Ac', '1xUOaqO_kqU', '9kUromZCP9M', 'cTrmlTw06KY', 'MNnvoPKcBSM', '6PwjoptTj5Q', '-HxKHUEwnug', 'r8p44wQMtNE', '2Rlo4gA5Y_Q', 'WNavHksmXnA', 'sbBdtFqHqvA', '3ZfKfkuYwyM', 'FVll9k_RUSg', 'SBlf1uukcm0', 'QZgY6D2s-nc', 'FuMxp_A1utI', 'CFNvij1f0Nk', 'EBBxZ3PLyrk', '8UfYrdmOl0I', 'yDyJe1nmSOM', 'eYJiOflZLn0', '1g-wANyGiR0', 'qgZVRbTQ-eQ', 'brQLpTnDwyg', 'I4MfgzvCPQs', 'u2MrTgBoqiI', 'rih9-80p0Ec', 'kT4rmfp5Jew', 'NtUSYNHmPyU', 'HxTbhLfbHtQ', 'a9hwXoCrEUs', 'x2BQyZorSQc', 'mhwstB-wax8', '-jtqMGKaw6c', '_jrD-EJnuak', 'E76kpPjxMcw', 'WjeNN7X3lRM', '56OmlPWDRjs', 'MEvTjiPu58s', 'q9Nuy7mFIsE', 'Wr5iA4k1X8w', 'jCUfqwy7bSs', 'OxY8VsfSNPA', 'xC9SxxjEviE', 'cVoZlYAsBWo', 'sfRcl5rmydI', '-9pCmXysOd0', 'NQflFk5WAO0', 'lH_fyyAImdY', 'Wly9_qN-jZ0', 'yhjXD8wJpkk', 'wP656kgwTgQ', 'baND9BoUHBk', '_0n1Q0CV-3A', '_1Q3VHCNfyg', 'Wnx-uM5Rn60', 'eULXLrKzPzE', 'YaaGvq2mcR0', 'RkSOvEw2unE', '_CEyRrYzPVk', 'IHG28kSNmXI', 'FGCd-h9sK7A', 'B1ntFD-57ow', '59IiApDiWjA', 'LylOnGRMvfw', 'l3_xOUBK5T4', 'KOajRmbroY0', '1tzRGkXZ-8I', 's1Do7ngr17k', 'YpZKwbdbsJ4', 'jqcNASh2FOk', 'pDeoBEojae4', '1UwPiBkvGQU', '4n3fkTq_p0o', '4TQIiVlHYxY', 'CWlOlophVhE', 'pIZNBTRYj_o', 'tsKqJay4ZRE', 'uqSVp3ggnr4', 'ZCYMAs4cqRU', '3YaxIdTe8Ic', 'yUFYnVXbLoY', 'trj5dsNWgJ8', 'pl7DE8RFfUc', '50Y5r9HeR2w', 'a9a_DM3Ynp0', 's1c3k9MfhA0', 'AOO5a_jUOzg', 'Je3Qu-xMuxM', 'Q0_ltg5IYgo', 'ji4qvi-4MZo', 'OhBVWX0IkIk', 'yl1pfOEvReM', 'aAYL2Pw3jig', 'lPpFFU9EMr8', 'Qd5651uHofM', 'XU49FSIx0_g', '8WN_Ro2aBmM', 'V7b2X8rqpsM', 'xj5m9tOKQok', 'kJQ_FsmU19g', 'DQ9M1J9-77Y', 'Eu_pTOlORk4', '1HDH4IbJArM', 'Z8SjYMTL7zA', 'xxXuYqUAnZg', 'glehaMc-w98', '8GQuyXIYlz4', 'x2X82ubHWGY', 'svUGFt3AF4w', 'x36boO6hWjM', 'laXhTcko-lg', 'NdXF3kmKCPY', 'mnlmlGgHYkw', 'JQzCq9HMVlI', 'f5cPzD2a_Ao', 'qppcCh5vuA0', 'QktohWYoU7o', 'Aga-fA6iUm4', 'Jxa1hZiYxCw', 'TG3VjJfExcg', '1hCz21GCFdw', 'byl48gjOGFA', 'RxMa6VD7DOE', 'LfUrHpgD9wM', '2f0OByvvkRw', '1KpDzlCVCWM', '9b7yNBLA1Jw', 'm9CyVxsE2FM', '4wMhXxZ1zNM', 'wstFwAyQqUU', 'sUV-nDUygMk', '5WHQtmbgGjg', 'eAH59Wh-Ymo', 'MzYMi0o_ZOI', '_POHeGxYCB4', 'udyaDDVJCgY', '2jmumX5cmjc', 'iq23VdtETZw', 'RFB3MibNEGs', 'Su7P2k5Q-AY', 'VJme28KSb6I', 'EZsihZg1EGs', '27s0tiCwKg8', 'totDkXxKOXg', 'kiCjb-5woXM', 'za3rlP9pJEU', 'LQJs8BHtTXg', 'ftrbdFGTQO4', 'UFG8RiMUGD0', 'V8kT6J_uoic', 'mlR9fCXfWyM', 'aMDdhSmE14Q', '86bAheOFJT8', 'Gh5YDe16n1Y', 'aXG5R4HRlgs', '4cJcCu1h1hY', '06-Sdo1Qkqk', 'zMFTLdqFUwQ', 'lASPp9stEYA', 'Sd8jhbF9_pc', '8HgLQGb907s', 'PQuLc-kEin0', 'TSZ9wPPcszo', 'lLZyRA7oLik', '7n5Dq-c0_Zw', 'otYgKPoHGMU', '8Kl2LcO9nBQ', 'TqM-rhKniLE', 'bAUN1GJD5BQ', 'hSldb9IMDVU', 'd747dgZqIwQ', 's6JjHAnCWqU', 'g5NG6mo1zGY', 'kAm6dKvFb78', 'dSZvXgu7Q2Q', 'x-Veqz6JpQY', '4TrT9tVjNJg', 'P8cP1ChW3io', 'hHpfGf_bFps', 'aTuonpTAIOw', 'hckQ0TZ1h4w', 'JSwT3vWazFo', 'qP-NvqHBfrk', 'CLATUuVcPBs', 'YGub8195Zus', 'cfv6nm4ykLY', 'TeS_Yq-7vHw', 'Y5szkAecabU', 'TNKZz-C0EOc', 'v54begBp3pE', '7YT8bfZI8fs', 'twstdwcxjdk', 'WMETBHvo-U4', 'urvVEQWbWak', '__CI6-fjbsU', 'P6mwnfqoNFg', 'YF8gc1jBiFM', 'xr ...
#         Video ID
# 0    kaS8fP12CGM
# 1    cHR-S4Ni7PE
# 2    SJek6PsN2xg
# 3    t1eGM-dTZu0
# 4    vLfV9PowEbw
# ..           ...
# 268  16xhpv13DsM
# 269  Hmy867m2QlQ
# 270  HZpUbBDWLK0
# 271  FNiXDiNsM9Q
# 272  BR_8AxIwKV8
#
# [273 rows x 1 columns]

# %%
#since the first extraction did not return view count and like count, i had to try again 
def get_videos_statistics(video_ids):
    video_stats_list = []

    for video_id in video_ids:
        request = youtube.videos().list(
            part='snippet,statistics',
            id=video_id
        )
        response = request.execute()

        if 'items' in response and len(response['items']) > 0:
            video = response['items'][0]
            snippet = video['snippet']
            statistics = video['statistics']

          
            title = snippet['title']
            view_count = statistics.get('viewCount', '0')
            like_count = statistics.get('likeCount', '0')
            comment_count = statistics.get('commentCount', '0')

          
            video_stats_list.append({
                'Video ID': video_id,
                'Title': title,
                'View Count': view_count,
                'Like Count': like_count,
                'Comment Count': comment_count
            })
        else:
            print(f"No data found for video ID: {video_id}")

    return pd.DataFrame(video_stats_list)



df_video_stats = get_videos_statistics(video_ids)


print(df_video_stats)


df_video_stats.to_csv('video_statistics.csv', index=False)
# Out:
#         Video ID                                              Title  \
# 0    kaS8fP12CGM  Project Blue Beam: Staging a Fake Alien Attack...
# 1    cHR-S4Ni7PE   COMPILATION: The Stories That Made Me a Believer
# 2    SJek6PsN2xg  Alien Implants Vol. 1: Devil’s Den UFO Encount...
# 3    t1eGM-dTZu0  Operation Sunray | Hunting the Entity in the T...
# 4    vLfV9PowEbw  Accidental Time Travelers | The Mystery and Sc...
# ..           ...                                                ...
# 268  16xhpv13DsM  Raining spiders, frogs, fish and ... meat. Yes...
# 269  Hmy867m2QlQ  ASMR: What it is, what it stands for and how i...
# 270  HZpUbBDWLK0  Top 10 Scariest Places You Can Actually Visit ...
# 271  FNiXDiNsM9Q      Top 10 Terrifying Animals That Actually Exist
# 272  BR_8AxIwKV8       15 Mind Blowing Math Facts | Insane but True
#
#     View Count Like Count Comment Count
# 0      1743020     127401         13238
# 1      2652407     115131          9988
# 2      2090591     109133          8092
# 3      2840332     121291          7222
# 4      2476400     109567         10919
# ..         ...        ...           ...
# 268     703263      41020          1561
# 269    1085587      75370          3954
# 270    1709119      91833          3355
# 271     559493      41337          1232
# 272    1738746      71073          4269
#
# [273 rows x 5 columns]

# %%
# Function to get video statistics by video ID
def get_video_statistics(video_id):
    request = youtube.videos().list(
        part='snippet,statistics',  # Include snippet and statistics parts
        id=video_id
    )
    response = request.execute()

    if 'items' in response and len(response['items']) > 0:
        video = response['items'][0]
        snippet = video['snippet']
        statistics = video['statistics']

        # Extract relevant data
        title = snippet['title']
        view_count = statistics.get('viewCount', '0')
        like_count = statistics.get('likeCount', '0')
        comment_count = statistics.get('commentCount', '0')

        # Print video details
        print(f"Title: {title}")
        print(f"View Count: {view_count}")
        print(f"Like Count: {like_count}")
        print(f"Comment Count: {comment_count}")

        return {
            'title': title,
            'view_count': view_count,
            'like_count': like_count,
            'comment_count': comment_count
        }
    else:
        print(f"No data found for video ID: {video_id}")
        return None


video_id = 'BR_8AxIwKV8'  

# Get video statistics
video_stats = get_video_statistics(video_id)
# Out:
# Title: 15 Mind Blowing Math Facts | Insane but True
# View Count: 1738746
# Like Count: 71073
# Comment Count: 4269

# %%
df_video_ids.to_csv('channel_video_ids.csv', index=False)

# %%
#getting videos that are shorts based on duration
